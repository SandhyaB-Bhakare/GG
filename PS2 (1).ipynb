# %% [markdown]
# Predict the house price
# Perform following tasks:
# 1. Pre-process the dataset.
# 2. Identify outliers.
# 3. Check the correlation.
# 4. Implement linear regression
# 5. Evaluate the models and compare their respective scores like R2, RMSE, etc.

# %%
import pandas as pd

# %%
import numpy as num
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv(r"C:\Users\Admin\Desktop\finalmock\House_Rent_Dataset.csv")

# %%
df
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     18-05-2022    2  10000  1100  Ground out of 2   Super Area
# 1     13-05-2022    2  20000   800       1 out of 3   Super Area
# 2     16-05-2022    2  17000  1000       1 out of 3   Super Area
# 3     04-07-2022    2  10000   800       1 out of 2   Super Area
# 4     09-05-2022    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  18-05-2022    2  15000  1000       3 out of 5  Carpet Area
# 4742  15-05-2022    3  29000  2000       1 out of 4   Super Area
# 4743  10-07-2022    3  35000  1750       3 out of 5  Carpet Area
# 4744  06-07-2022    3  45000  1500     23 out of 34  Carpet Area
# 4745  04-05-2022    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     18-05-2022    2  10000  1100  Ground out of 2   Super Area
# 1     13-05-2022    2  20000   800       1 out of 3   Super Area
# 2     16-05-2022    2  17000  1000       1 out of 3   Super Area
# 3     04-07-2022    2  10000   800       1 out of 2   Super Area
# 4     09-05-2022    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  18-05-2022    2  15000  1000       3 out of 5  Carpet Area
# 4742  15-05-2022    3  29000  2000       1 out of 4   Super Area
# 4743  10-07-2022    3  35000  1750       3 out of 5  Carpet Area
# 4744  06-07-2022    3  45000  1500     23 out of 34  Carpet Area
# 4745  04-05-2022    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# ...

# %%
df.dtypes
# Out:
# Posted On            object
# BHK                   int64
# Rent                  int64
# Size                  int64
# Floor                object
# Area Type            object
# Area Locality        object
# City                 object
# Furnishing Status    object
# Tenant Preferred     object
# Bathroom              int64
# Point of Contact     object
# dtype: object

# %%
df=df.drop('Posted On',axis=1)

# %%
df=df.drop('Floor',axis=1)

# %%
df=df.drop('Point of Contact',axis=1)

# %%
df=df.drop('Area Locality',axis=1)

# %%
def find_outliers_IQR(df):
   q1 = df.quantile(0.25)
   q3 = df.quantile(0.75)
   IQR = q3-q1
   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]
   return outliers

# %%
outliers = find_outliers_IQR(df["Rent"])

# %%
df
# Out:
#       BHK   Rent  Size    Area Type       City Furnishing Status  \
# 0       2  10000  1100   Super Area    Kolkata       Unfurnished
# 1       2  20000   800   Super Area    Kolkata    Semi-Furnished
# 2       2  17000  1000   Super Area    Kolkata    Semi-Furnished
# 3       2  10000   800   Super Area    Kolkata       Unfurnished
# 4       2   7500   850  Carpet Area    Kolkata       Unfurnished
# ...   ...    ...   ...          ...        ...               ...
# 4741    2  15000  1000  Carpet Area  Hyderabad    Semi-Furnished
# 4742    3  29000  2000   Super Area  Hyderabad    Semi-Furnished
# 4743    3  35000  1750  Carpet Area  Hyderabad    Semi-Furnished
# 4744    3  45000  1500  Carpet Area  Hyderabad    Semi-Furnished
# 4745    2  15000  1000  Carpet Area  Hyderabad       Unfurnished
#
#       Tenant Preferred  Bathroom
# 0     Bachelors/Family         2
# 1     Bachelors/Family         1
# 2     Bachelors/Family         1
# 3     Bachelors/Family         1
# ...

# %%
import matplotlib.pyplot as plp

# %%
print("number of outliers: "+ str(len(outliers)))
print("max outlier value: "+ str(outliers.max()))
print("min outlier value: "+ str(outliers.min()))
# Out:
# number of outliers: 520
# max outlier value: 3500000
# min outlier value: 68000

# %%
#from sklearn.preprocessing import StandardScaler

# %%
#sc=StandardScaler()

# %%
# df['Rent']=sc.fit_transform(df[['Rent']])

# %%
# df['Size']=sc.fit_transform(df[['Size']])

# %%
# df['Bathroom']=sc.fit_transform(df[['Bathroom']])

# %%
# df['BHK']=sc.fit_transform(df[['BHK']])

# %%
df
# Out:
#       BHK   Rent  Size    Area Type       City Furnishing Status  \
# 0       2  10000  1100   Super Area    Kolkata       Unfurnished
# 1       2  20000   800   Super Area    Kolkata    Semi-Furnished
# 2       2  17000  1000   Super Area    Kolkata    Semi-Furnished
# 3       2  10000   800   Super Area    Kolkata       Unfurnished
# 4       2   7500   850  Carpet Area    Kolkata       Unfurnished
# ...   ...    ...   ...          ...        ...               ...
# 4741    2  15000  1000  Carpet Area  Hyderabad    Semi-Furnished
# 4742    3  29000  2000   Super Area  Hyderabad    Semi-Furnished
# 4743    3  35000  1750  Carpet Area  Hyderabad    Semi-Furnished
# 4744    3  45000  1500  Carpet Area  Hyderabad    Semi-Furnished
# 4745    2  15000  1000  Carpet Area  Hyderabad       Unfurnished
#
#       Tenant Preferred  Bathroom
# 0     Bachelors/Family         2
# 1     Bachelors/Family         1
# 2     Bachelors/Family         1
# 3     Bachelors/Family         1
# ...

# %%
df = pd.get_dummies(df, columns=['City','Furnishing Status','Area Type','Tenant Preferred'], drop_first=True)

# %%
df
# Out:
#       BHK   Rent  Size  Bathroom  City_Chennai  City_Delhi  City_Hyderabad  \
# 0       2  10000  1100         2             0           0               0
# 1       2  20000   800         1             0           0               0
# 2       2  17000  1000         1             0           0               0
# 3       2  10000   800         1             0           0               0
# 4       2   7500   850         1             0           0               0
# ...   ...    ...   ...       ...           ...         ...             ...
# 4741    2  15000  1000         2             0           0               1
# 4742    3  29000  2000         3             0           0               1
# 4743    3  35000  1750         3             0           0               1
# 4744    3  45000  1500         2             0           0               1
# 4745    2  15000  1000         2             0           0               1
#
#       City_Kolkata  City_Mumbai  Furnishing Status_Semi-Furnished  \
# ...

# %%
# from sklearn.preprocessing import LabelEncoder

# %%
# label_Encoder=LabelEncoder()

# %%
# df['Area Locality']=label_Encoder.fit_transform(df['Area Locality'])

# %%
df
# Out:
#       BHK   Rent  Size  Bathroom  City_Chennai  City_Delhi  City_Hyderabad  \
# 0       2  10000  1100         2             0           0               0
# 1       2  20000   800         1             0           0               0
# 2       2  17000  1000         1             0           0               0
# 3       2  10000   800         1             0           0               0
# 4       2   7500   850         1             0           0               0
# ...   ...    ...   ...       ...           ...         ...             ...
# 4741    2  15000  1000         2             0           0               1
# 4742    3  29000  2000         3             0           0               1
# 4743    3  35000  1750         3             0           0               1
# 4744    3  45000  1500         2             0           0               1
# 4745    2  15000  1000         2             0           0               1
#
#       City_Kolkata  City_Mumbai  Furnishing Status_Semi-Furnished  \
# ...

# %%
# df['Area Locality']=sc.fit_transform(df[['Area Locality']])

# %%
df
# Out:
#       BHK   Rent  Size  Bathroom  City_Chennai  City_Delhi  City_Hyderabad  \
# 0       2  10000  1100         2             0           0               0
# 1       2  20000   800         1             0           0               0
# 2       2  17000  1000         1             0           0               0
# 3       2  10000   800         1             0           0               0
# 4       2   7500   850         1             0           0               0
# ...   ...    ...   ...       ...           ...         ...             ...
# 4741    2  15000  1000         2             0           0               1
# 4742    3  29000  2000         3             0           0               1
# 4743    3  35000  1750         3             0           0               1
# 4744    3  45000  1500         2             0           0               1
# 4745    2  15000  1000         2             0           0               1
#
#       City_Kolkata  City_Mumbai  Furnishing Status_Semi-Furnished  \
# ...

# %%
x=df.drop('Rent',axis=1)
y=df.Rent

# %%
X_Train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(X_Train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': y_pred})
print(df.head(10))
# Out:
#       Actual      Predicted
# 1566   16000   29893.756920
# 3159   12000   18432.675980
# 538    28000   67643.458446
# 2630    8000   75217.484580
# 4418   46000   90303.000338
# 4679   17000   16484.453461
# 1181   57000   81679.752267
# 1957    9500   14615.466256
# 1344  400000  181726.385547
# 3410   15000    4430.096718

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
# Evaluate the model using Root Mean Squared Error (RMSE), Mean Absolute Error (MAE), and Mean Squared Error (MSE)
rmse = mean_squared_error(Y_test, y_pred, squared=False)
mae = mean_absolute_error(Y_test, y_pred)
mse = mean_squared_error(Y_test, y_pred)
r2=r2_score(Y_test,y_pred)

print('MSE:', mse)
print('RMSE:', rmse)
print('MAE:', mae)
# Out:
# MSE: 1915300006.7548661
# RMSE: 43764.14064910753
# MAE: 22439.91108280518

# %%
r2
# Out:
# 0.5194186316622325
